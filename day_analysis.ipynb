# %%
import pandas as pd

with open('Project.csv', 'r') as f:
    df = pd.read_csv(f)
selected_features_df = df[['Day of Week', 'Total_Bill']]
selected_features_df
# Out:
#         Day of Week  Total_Bill
# 0                 3         3.0
# 1                 4         3.0
# 2                 4         3.0
# 3                 4         3.0
# 4                 5         3.0
# ...             ...         ...
# 149111            2        17.0
# 149112            5       360.0
# 149113            5       360.0
# 149114            5       360.0
# 149115            4       360.0
#
# [149116 rows x 2 columns]

# %%
# print(selected_features_df['Day of Week'].unique())
group_by = selected_features_df.groupby('Day of Week')['Total_Bill'].sum()
group_by
# Out:
# Day of Week
# 0    101677.28
# 1     99455.94
# 2    100313.54
# 3    100767.78
# 4    101373.00
# 5     96894.48
# 6     98330.31
# Name: Total_Bill, dtype: float64

# %%
import matplotlib.pyplot as plt
day_of_week = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
# plt.plot(x, group_by, marker='o', color='b', linestyle='-', label='نمودار خطی')
# plt.pie(group_by, labels=day_of_week, autopct='%1.1f%%')
# plt.show()

fig, axes = plt.subplots(1, 2, figsize=(20,5))

axes[0].plot(day_of_week, group_by, marker='o', color='b', linestyle='-', label='نمودار خطی')

axes[1].pie(group_by, labels=day_of_week, autopct='%1.1f%%')

plt.tight_layout()

plt.show()
